# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import os
import requests
import time
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# # Data Preparation

# %%
# Specify the folder where the injury datasets are stored
data_folder = "Data\\InjuryDataPerLeaguePerSeason"

# List to store individual DataFrames
dataframes = []

# Loop through each file in the data folder
for file in os.listdir(data_folder):
    if file.startswith("player_injury_data_") and file.endswith(".csv"):
        file_path = os.path.join(data_folder, file)
        print("Reading: ", file_path)
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Extract league name and season year from the file name
        parts = file.split('_')
        league_name = '_'.join(parts[3:-1])  # Handle potential underscores in league names
        season_year = parts[-1].split('.')[0]
        
        # Add league and season year columns
        df['League'] = league_name
        df['Season Year'] = season_year
        
        # Append to the list of DataFrames
        dataframes.append(df)

# Merge all DataFrames on the 'Player ID' column
merged_df = pd.concat(dataframes, ignore_index=True)

# Sort the merged dataset by 'Player ID', 'Season Year', and 'League'
merged_df.sort_values(by=['Player ID', 'Season Year', 'League'], inplace=True)

# # Save the merged dataset to a CSV file
# output_path = os.path.join(data_folder, 'merged_player_injury_data.csv')
# merged_df.to_csv(output_path, index=False)

# print(f"Merged dataset saved to {output_path}")
# Out:
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Bundesliga_2021.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Bundesliga_2022.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Bundesliga_2023.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Bundesliga_2024.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_La Liga_2021.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_La Liga_2022.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_La Liga_2023.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_La Liga_2024.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Premier League_2021.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Premier League_2022.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Premier League_2023.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Premier League_2024.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Serie A_2021.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Serie A_2022.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Serie A_2023.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Serie A_2024.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Süper Lig_2021.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Süper Lig_2022.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Süper Lig_2023.csv
# Reading:  Data\InjuryDataPerLeaguePerSeason\player_injury_data_Süper Lig_2024.csv

# %%
# Create dataframes
df_injuries = pd.read_csv('df_injuries.csv')
df_season_stats = pd.read_csv('df_season_stats.csv')

# Perform the left merge
df_merged = pd.merge(
    df_injuries,
    df_season_stats,
    on=["Player", "Player ID", "Season"],
    how="left",  # Left merge to keep all rows from df_injuries
    suffixes=("_injuries", "_stats"),
)

df_merged.to_csv('dataset.csv', index=False)

# %%
df_merged
# Out:
#                 Player  Player ID Season                  Injury  \
# 0      Eldin Jakupović       2857  22/23              Leg injury
# 1      Eldin Jakupović       2857  22/23              Leg injury
# 2         James Milner       3333  24/25        Hamstring injury
# 3         James Milner       3333  23/24           Muscle injury
# 4         James Milner       3333  23/24           Muscle injury
# ...                ...        ...    ...                     ...
# 98333     Berhan Deniz    1196380  23/24         Inguinal hernia
# 98334     Berhan Deniz    1196380  23/24         Inguinal hernia
# 98335     Berhan Deniz    1196380  23/24         Inguinal hernia
# 98336      Erdem Güleç    1230230  24/25            Broken tibia
# 98337     Eymen Yurdcu    1292650  24/25  Cruciate ligament tear
#
#                From         Until  Days Out Games Missed  \
# 0      Apr 13, 2023   May 8, 2023   25 days            5
# 1      Apr 13, 2023   May 8, 2023   25 days            5
# 2      Aug 31, 2024  Sep 14, 2024   14 days            2
# 3      Jan 31, 2024  Jun 12, 2024  133 days           19
# 4      Jan 31, 2024  Jun 12, 2024  133 days           19
# ...             ...           ...       ...          ...
# 98333  Apr 26, 2024  May 27, 2024   31 days            5
# 98334  Apr 26, 2024  May 27, 2024   31 days            5
# 98335  Apr 26, 2024  May 27, 2024   31 days            5
# 98336  Jul 20, 2024           NaN  134 days           14
# 98337  Aug 22, 2024  Mar 22, 2025  212 days           25
#
#                 Club_injuries             Competition Appearances  \
# 0              Los Angeles FC  CONCACAF Champions Cup           -
# 1              Los Angeles FC          Premier League           -
# 2      Brighton & Hove Albion          Premier League           3
# 3      Brighton & Hove Albion          Premier League          15
# 4      Brighton & Hove Albion                  FA Cup           -
# ...                       ...                     ...         ...
# 98333              Samsunspor           U19 Süper Lig          11
# 98334              Samsunspor               Süper Lig           1
# 98335              Samsunspor          Türkiye Kupasi           3
# 98336               Sivasspor                     NaN         NaN
# 98337               Sivasspor               Süper Lig           -
#
#            Club_stats Minutes Played
# 0         CONCACAF CL              -
# 1      Premier League              -
# 2      Premier League           172'
# 3      Premier League           778'
# 4              FA Cup              -
# ...               ...            ...
# 98333   U19 Süper Lig           770'
# 98334       Süper Lig             3'
# 98335  Türkiye Kupasi            98'
# 98336             NaN            NaN
# 98337       Süper Lig              -
#
# [98338 rows x 13 columns]

# %%
df_merged.isna().sum()
# Out:
# Player              0
# Player ID           0
# Season              0
# Injury              0
# From               12
# Until             712
# Days Out            0
# Games Missed        0
# Club_injuries       0
# Competition       706
# Appearances       702
# Club_stats        702
# Minutes Played    702
# dtype: int64

# %%
df_merged['Injury'].nunique()
# Out:
# 323

# %%
df_merged['Injury'].unique()
# Out:
# array(['Leg injury', 'Hamstring injury', 'Muscle injury', 'concussion',
#        'unknown injury', 'Calf injury', 'Hamstring strain', 'Hip injury',
#        'bruise', 'Knee surgery', 'Knee problems',
#        'Achilles tendon problems', 'Achilles tendon irritation',
#        'Knee injury', 'Muscle fatigue', 'Adductor injury', 'Corona virus',
#        'Calf muscle tear', 'influenza', 'Thigh problems', 'surgery',
#        'strain', 'Cruciate ligament tear', 'muscular problems',
#        'Broken hand', 'Ill', 'Acromioclavicular joint dislocation',
#        'Torn muscle fiber', 'Torn muscle bundle',
#        'Internal ligament tear', 'Ankle injury', 'Knee bruise',
#        'Ligament injury', 'Abdominal problems', 'minor knock', 'Knock',
#        'Broken nose bone', 'Back problems', 'Broken finger', 'Virus',
#        'Rest', 'Hip flexor problems', 'Arm injury', 'Adductor pain',
#        'Metacarpal fracture', 'Internal ligament strain',
#        'Dental surgery', 'flesh wound', 'Bursitis', 'Quarantine',
#        'Rib fracture', 'Hand injury', 'Mononucleation',
#        'Ligament stretching', 'Fitness', 'Tendon rupture', 'Tendonitis',
#        'Edema in the knee', 'Bruised knee', 'muscle stiffness',
#        'Tear of the lateral meniscus', 'Head injury',
#        'Outer ligament problems', 'Calf strain',
#        'Syndesmotic ligament tear', 'heart problems', 'Groin problems',
#        'flu', 'Fever', 'Lumbago', 'Hamstring muscle injury',
#        'Injury to the ankle', 'Shoulder injury', 'Meniscus damage',
#        'Wrist injury', 'Broken foot', 'Cruciate ligament injury',
#        'Groin injury', 'Thumb injury', 'Cartilage damage', 'Foot injury',
#        'Cheekbone bruise', 'Broken cheekbone', 'Chest injury',
#        'Back injury', 'Forearm fracture', 'Broken fibula',
#        'Broken collarbone', 'Hip problems', 'fatigue fracture',
#        'Broken shoulder', 'Bone bruise', 'Calf problems', 'Bruised ribs',
#        'Bone edema', 'Torn thigh muscle', 'Stomach flu', 'infection',
#        'ankle sprain', 'stomach problems', 'Fracture of fibula shaft',
#        'Ankle sprain', 'Inner ligament injury', 'Groin strain',
#        'Muscle tear', 'Calf stiffness', 'Blockage in the back',
#        'Lower leg fracture', 'Shoulder joint contusion',
#        'Capsular injury', 'Finger injury',
#        'Inner ligament stretch of the knee', 'Elbow injury',
#        'Eyebow fracture', 'Metatarsal fracture', 'Sciatica problems',
#        'Left hip flexor problems', 'Knee medial ligament tear',
#        'Ankle problems', 'Toe injury', 'Cruciate ligament surgery',
#        'Food poisoning', 'Foot bruise', 'Intestinal virus',
#        'Ankle ligament tear', 'Inguinal hernia',
#        'Torn muscle fiber in the adductor area', 'Broken tibia',
#        'fracture', 'inflammation', 'sprain', 'Ankle surgery',
#        'Meniscus injury', 'Cervical spine injury', 'cold',
#        'Achilles tendon rupture', 'Abdominal muscle strain',
#        'Tendon irritation', 'Meniscus tear', 'Muscle fiber tear',
#        'Lumbar vertebra fracture', 'Patellar tendon problems',
#        'Sore muscles', 'Injury to abdominal muscles', 'Contracture',
#        'Broken ankle', 'Inner knee ligament tear',
#        'Torn lateral ankle ligament', 'Heel injury', 'Nose surgery',
#        'Muscle strain', 'Appendectomy', 'laceration', 'Broken arm',
#        'Pubic bone irritation', 'Foot surgery', 'Muscle contusion',
#        'Outer ligament tear', 'Strain in the thigh and gluteal muscles',
#        'Nose injury', 'Partial damage to the cruciate ligament',
#        'Partial muscle tear', 'traffic accident', 'Patellar tendon tear',
#        'Broken toe', 'Facial injury', 'Inflammation in the ankle joint',
#        'Bruise on ankle', 'Broken petrous bone in the ear', 'Arthroscopy',
#        'Lumbar vertebra problems', 'chickenpox', 'Neck injury',
#        'Torn ankle ligaments', 'Pubalgia', 'Inflammation of pubic bone',
#        'Heel problems', 'Shin injury', 'Groin surgery',
#        'Inner ligament tear in ankle joint', 'Eye injury',
#        'Stress reaction of the bone', 'Torn lateral knee ligament',
#        'Inflammation in the knee', 'Dead leg', 'Pelvic injury',
#        'Facial fracture', 'Pneumothorax', 'Whiplash',
#        'Peroneus tendon injury', 'Collateral ligament injury',
#        'Overstretching of the syndesmotic ligament', 'Scaphoid fracture',
#        'laceration wound', 'Partial tear of the plantar fascia',
#        'Syndesmosis ligament tear', 'Crack bruise', 'Cut', 'pneumonia',
#        'Overstretching', 'Heel spur', 'Herniated disc',
#        'Vertebral injury', 'Appendicitis', 'Patellar tendon rupture',
#        'Swine flu', 'Capsule rupture', 'Cyst on jaw', 'Toothache',
#        'Tendon tear', 'Torn knee ligaments', 'Patellar tendon irritation',
#        'Fissure of the fibula', 'Knee collateral ligament strain',
#        'Achilles tendon surgery', 'Capsular tear of ankle joint',
#        'Cruciate ligament strain', 'Shin bruise', 'Tonsillitis',
#        'Collateral ligament tear', 'Compartment syndrome',
#        'Knee collateral ligament tear', 'Nerval disease', 'Bruised back',
#        'Kidney stone surgery', 'Inflammation of ligaments in the knee',
#        'Pelvic contusion', 'Bone sprain', 'Tibia and fibula fracture',
#        'Hip bruise', 'Elbow fracture', 'malaria', 'Tooth infection',
#        'Achilles tendon contusion', 'Arch problems', 'Torn ligaments',
#        'Metatarsal bruise', 'Skull base fracture', 'Broken leg',
#        'Achilles heel problems', 'Femoral neck fracture', 'Ligament tear',
#        'Right hip flexor problems', 'Femoral fracture', 'pinched nerve',
#        'Hairline fracture in the fibula', 'angina', 'Broken jaw',
#        'Inflammation of the leg skin', 'Adductor tear',
#        'Inflammation in the head of the fibula', 'depression',
#        'bronchitis', 'Bruise on the ankle joint', 'Cancer',
#        'Remove screws/nails', 'Hairline crack in foot', 'contortion',
#        'Wrist fracture', 'Bone inflammation',
#        'Hairline fracture in the muscles', 'Lung contusion',
#        'Skull fracture', 'Inflammation of the biceps tendon in the thigh',
#        'collapsed lung', 'open wound', 'Coccyx bruise', 'inflamed wound',
#        'Dislocation of the kneecap', 'Vein occlusion', 'Testicle rupture',
#        'Broken thumb', 'Broken kneecap', 'Inner ankle ligament tear',
#        'Insect bite', 'Fracture of the eye socket',
#        'double ligament tear', 'Dislocation fracture of the ankle joint',
#        'Cyst in the knee', 'Pubic bone bruise', 'Testicular cancer',
#        'Bone marrow swelling', 'Patellar tendon dislocation',
#        'Herniated umbilical button', 'Compression of the spine',
#        'Inflammation of the sole of the foot', 'Tibial head contusion',
#        'Pelvic obliquity', 'Torn ligaments in the tarsus',
#        'Cervical vertebra fracture', 'Hairline crack in middle finger',
#        'allergic reaction', 'Scaphoid surgery', 'Frontal sinus fracture',
#        'meningitis', 'Neck bruise', 'Balance disorder',
#        'Circulation problems', 'Inflammation in the spine',
#        'Kidney problems', 'Cerebral hemorrhage',
#        'Collateral ankle ligament tear', 'Fracture of frontal bone',
#        'Skin disease', 'Midfacial fracture', 'Intestinal surgery',
#        'Partial patellar tendon tear', 'Ruptured eardrum',
#        'Lymphatic cancer', 'Shingles', 'Toe joint capsular tear',
#        'abscess', 'Bruise on shinbone', 'Collateral ligament ripture',
#        'Cheekbone surgery', 'Blood poisoning', 'Meniscus irritation',
#        'Inflammation of the pancreas', 'Patellar tendinopathy syndrome',
#        'Cracked bone', 'combustion', 'Longitudinal tendon tear',
#        'Bone splintering'], dtype=object)
